# %%
a, b, c = map(int, input().split())
max=0
if a>b and a>c:
    max=a
elif b>c:
    max=b
else:
    max=c
print(max)
# Out:
# 100

# %%
n = input("Nhập số nguyên n: ")
print("Các chữ số đảo ngược là:", end=" ")
for i in range(len(n)-1, -1, -1):
    print(n[i], end="")
# Out:
# Các chữ số đảo ngược là: 000001

# %%
n=int(input("nhap so tu nhien: "))
if n&(n-1)==0:
    print("True")
else: print("False")
# Out:
# False

# %%
n, m = map(int, input("nhap hai so n va m ").split())
print("lay n chia m kqua thu dc la: ",n//m)
# Out:
# lay n chia m kqua thu dc la:  9

# %%
import math
n, m = map(int, input("nhap hai so n va m ").split())
print("lay n chia m kqua thu dc la: ", math.ceil(n/ m))
# Out:
# lay n chia m kqua thu dc la:  1

# %%
n=int(input("Nhap so nguyen duong n: "))
if n%2==0:
    print("Even")
else:
    print("Old")
# Out:
# Old

# %%
a,b = map(int, input("nhap hai so nguyen: ").split())
if a<0 and b<0:
    print("yes")
else:
    print("no")

# %%
a=input("Nhập chuỗi a: ")
b=input("Nhập chuỗi b: ")
if len(a)>len(b):
    print("True")
else:
    print("False")
# Out:
# False

# %%
a=int(input("Nhập cạnh a: "))
b=int(input("Nhập cạnh b: "))
c=int(input("Nhập cạnh c: "))
if a+b<=c or a+c<=b or b+c<=a or a<=0 or b<=0 or c<=0:
    print("No")
else: print("Yes")
# Out:
# No

# %%
a=int(input("Nhập số nguyên a: "))
b=int(input("Nhập số nguyên b: "))
c=int(input("Nhập số nguyên c: "))
d=int(input("Nhập số nguyên d: "))
if a>=b and a>=c and a>=d:
    print(a)
elif b>=a and b>=c and b>=d:
    print(b)
elif c>=a and c>= b and c>=d:
    print(c)
else: print(d)
# Out:
# 9999

# %%
a=int(input("Nhập cạnh a: "))
b=int(input("Nhập cạnh b: "))
c=int(input("Nhập cạnh c: "))
if a+b<=c or a+c<=b or b+c<=a or a<=0 or b<=0 or c<=0:
    print("Không phải tam giác")
elif a==b==c: print("tam giác đều")
elif a==b or b==c or c==a: print("tam giác cân")
else: print("tam giác thường")
# Out:
# Không phải tam giác

# %%
sonam=int(input("Nhập số năm: "))
if sonam%400==0 or sonam%4==0 and sonam%100!=0:
    print("Yes")
else: print("No")
# Out:
# Yes

# %%
sodien=int(input("nhập số điện: "))
tiendien=0
if   0<sodien and sodien<=50:
    tiendien=sodien*1500
elif   50< sodien and sodien <=100:
        tiendien=50*1500 + (sodien-50)*2000
elif sodien>100: tiendien= 1500*50 + 50*2000 + (sodien-100)*3000

print(tiendien)
# Out:
# 175000

# %%
a=float(input("nhập số thực a: "))
b=float(input("nhập số thực b: "))
if a==0.0 and b==0.0: print("vô số nghiệm")
elif a==0.0: print("vô nghiệm")
else: print(round(-b/a,2))
# Out:
# 3.0

# %%
diem=float(input("nhập điểm: "))
if diem>=8.0: print("Giỏi")
elif diem>=6.5: print("Khá")
elif diem>=5.0:print("Trung bình")
else: print("Yếu")
# Out:
# Yếu

# %%
a=float(input("Nhập số thục a: "))
tronxuong=0
tronlen=0
gannhat=0
if a>=0:
 tronxuong=int(a)
 if a-int(a)==0.0:
   tronlen=int(a)
 else:
    tronlen=int(a)+1
else:
    tronxuong=int(a)-1
    if a-int(a)==0.0:
      tronlen=int(a)
    else:
     tronlen=int(a) 

if a>=0:
 gannhat=int(a+0.5)
else:
   gannhat=int(a-0.5)
print(tronlen,tronxuong,gannhat)
# Out:
# 8 7 7
