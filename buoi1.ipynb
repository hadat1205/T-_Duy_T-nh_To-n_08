# %%
#W2A1
'print("Hello word!")'

# %%
#W2A2
nhapten = input("Nhập tên của bạn: ")
print("Xin chào", nhapten)

# %%
#W2A10
a,b,c=input("nhap ten 3 ban: ").split()
print("hi", c,b, "and", a )

# %%
#W2A16
print("Spring \n Summer \n Autumn \n Winter")

# %%
#W2A17
print("*")
print("***")
print("*****")

# %%
#W2A18
print('''### # #   ### ###
 #  #  #   #   #
 #  #   #  #   #
 #  #  #   #   #
 #  # #    #   # ''')
# Out:
# ### # #   ### ###
#  #  #  #   #   #
#  #  #   #  #   #
#  #  #  #   #   #
#  #  # #    #   #

# %%
#W2A20
print("January\nFebruary\nMarch\nApril\nMay\nJune\nJuly\nAugust\nSeptember\nOctober\nNovember\nDecember ")

# %%
#W2A19
print("Monday\nTuesday\nWednesday\nThursday\nFriday\nSaturday\nSunday ")

# %%
#W2A21
for i in range (10):
     print("Hello, world")
