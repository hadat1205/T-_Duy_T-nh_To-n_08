# %%
#W2a3
a, b=map(int, input("nhap hai so nguyen a va b").split())
print("tong: ",a+b)
print("hieu: ",a-b)
print("tich: ",a*b)
print("chia lay phan dư", a%b)
print("thuonh: ", round(a/b,2))
# Out:
# tong:  7
# hieu:  -1
# tich:  12
# chia lay phan dư 3
# thuonh:  0.75

# %%
#W2a4
a1, b1, c1, a2, b2,a3 = map(int, input("nhap cac dau diem: ").split())
tb=((a1 + b1 + c1)+(a2+b2)*2+a3*3)/10
print("diem trung binh: ",round(tb, 1))
# Out:
# diem trung binh:  6.2

# %%
#W2a5
a, b = map(int, input("nhập hai số nguyên a và b: ").split())
print("a mũ b bằng: ", a**b)
# Out:
# a mũ b bằng:  8

# %%
#w2a6
a=input("nhập chữ cái thg từ a->z: ")
b=ord(a)-32
print("đoạn mã unicode của a là: ", ord(a))
print("chữ cái in hoa của a là : ",chr(b))
# Out:
# đoạn mã unicode của a là:  103
# chữ cái in hoa của a là :  G

# %%
#w2a7
A = ((13 ** 2) * 3)+5
B = 13**(2*3) + 5
print(A, B)
# Out:
# 512 4826814

# %%
#w2a8
a=int(input("nhập nhiệt độ theo thang đô C: "))
print("nhiệt độ theo thang nhiệt độ F là: ",round(a*9/5+32,2))
# Out:
# nhiệt độ theo thang nhiệt độ F là:  39.2

# %%
#w2a9
x=int(input("nhập số tiền của đồng hồ"))
b=x+10+x*1.4
print("số tiền phải trả là: ", round(b,2))
# Out:
# số tiền phải trả là:  24.4

# %%
#w2a11
a, b = map(int, input("nhập lần lượt số giờ và só phút: ").split())
print("số giờ: ", a, "số phút chuyển sang giâay là ", b*60)
# Out:
# số giờ:  5 số phút chuyển sang giâay là  2520

# %%
#w2a12
n=int(input("nhập độ dài cạnh của hình lập phương: "))
print("số nhãn dán cần sử dụng là: ", 6*(n**2))
# Out:
# số nhãn dán cần sử dụng là:  54

# %%
#w2a13
a, b = map(int, input("nhập hai số nguyên dương a và b: ").split())
print("hàng đơn vị của tích a và b là: ", (a*b)%10)
# Out:
# hàng đơn vị của tích a và b là:  6

# %%
#wa14
a, b = map(int, input("nhập hai số a và b").split())
a, b =b, a
print("già trị của a là: ",a,  "giá trị của b là: ",b )
# Out:
# già trị của a là:  4 giá trị của b là:  3

# %%
#w2a5
n=int(input("nhập số nguyên dương: "))
a=1
for i in range (n):
 a=a+i*12

print("tổng số sao là: ",a)
# Out:
# tổng số sao là:  73
